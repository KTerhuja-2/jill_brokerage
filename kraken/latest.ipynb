# %%
# !pip install -q condacolab

# %%
import condacolab
condacolab.install() # expect a kernel restart
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
! conda install kraken2 bracken
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - bracken
#   - kraken2
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
! wget https://genome-idx.s3.amazonaws.com/kraken/k2_standard_08gb_20240605.tar.gz
# Out:
# --2024-10-17 08:45:06--  https://genome-idx.s3.amazonaws.com/kraken/k2_standard_08gb_20240605.tar.gz
# Resolving genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)... 52.216.24.4, 3.5.7.203, 3.5.28.145, ...
# Connecting to genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)|52.216.24.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5909794252 (5.5G) [application/x-tar]
# Saving to: ‘k2_standard_08gb_20240605.tar.gz’
#
# k2_standard_08gb_20 100%[===================>]   5.50G  25.7MB/s    in 4m 18s
#
# 2024-10-17 08:49:25 (21.8 MB/s) - ‘k2_standard_08gb_20240605.tar.gz’ saved [5909794252/5909794252]

# %%
! tar -xvzf /content/k2_standard_08gb_20240605.tar.gz -C /content/db
# Out:
# hash.k2d
# opts.k2d
# taxo.k2d
# standard08gb.md5
# inspect.txt
# unmapped_accessions.txt
# ktaxonomy.tsv
# library_report.tsv
# database100mers.kmer_distrib
# database150mers.kmer_distrib
# database200mers.kmer_distrib
# database250mers.kmer_distrib
# database300mers.kmer_distrib
# database50mers.kmer_distrib
# database75mers.kmer_distrib
# seqid2taxid.map

# %%
! conda install bioconda::kraken2
# Out:
# Channels:
#  - conda-forge
#  - bioconda
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bioconda::kraken2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blast-2.15.0               | pl5321h6f7f691_1       146.0 MB  bioconda
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     curl-8.5.0                 |       hca28451_0          93 KB  conda-forge
#     entrez-direct-22.4         |       he881be0_0        14.0 MB  bioconda
#     gettext-0.22.5             |       he02047a_3         468 KB  conda-forge
#     gettext-tools-0.22.5       |       he02047a_3         2.6 MB  conda-forge
#     kraken2-2.1.3              | pl5321hdcf5f25_2         257 KB  bioconda
#     libasprintf-0.22.5         |       he8f35ee_3          42 KB  conda-forge
#     libasprintf-devel-0.22.5   |       he8f35ee_3          33 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgettextpo-0.22.5        |       he02047a_3         167 KB  conda-forge
#     libgettextpo-devel-0.22.5  |       he02047a_3          36 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     libidn2-2.3.7              |       hd590300_0         124 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     ncbi-vdb-3.1.1             |       h4ac6f70_2        10.6 MB  bioconda
#     openssl-3.3.2              |       hb9d3cd8_0         2.8 MB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     perl-5.32.1                | 7_hd590300_perl5        12.7 MB  conda-forge
#     perl-archive-tar-2.40      | pl5321hdfd78af_0          33 KB  bioconda
#     perl-carp-1.50             | pl5321hd8ed1ab_0          22 KB  conda-forge
#     perl-common-sense-3.75     | pl5321hd8ed1ab_0          20 KB  conda-forge
#     perl-compress-raw-bzip2-2.201| pl5321h166bdaf_0          54 KB  conda-forge
#     perl-compress-raw-zlib-2.202| pl5321h166bdaf_0          83 KB  conda-forge
#     perl-encode-3.21           | pl5321hb9d3cd8_1         1.7 MB  conda-forge
#     perl-exporter-5.74         | pl5321hd8ed1ab_0          19 KB  conda-forge
#     perl-exporter-tiny-1.002002| pl5321hd8ed1ab_0          28 KB  conda-forge
#     perl-extutils-makemaker-7.70| pl5321hd8ed1ab_0         154 KB  conda-forge
#     perl-io-compress-2.201     | pl5321hdbdd923_2          84 KB  bioconda
#     perl-io-zlib-1.14          | pl5321hdfd78af_0          12 KB  bioconda
#     perl-json-4.10             | pl5321hdfd78af_1          56 KB  bioconda
#     perl-json-xs-4.03          | pl5321h4ac6f70_3          75 KB  bioconda
#     perl-list-moreutils-0.430  | pl5321hdfd78af_0          32 KB  bioconda
#     perl-list-moreutils-xs-0.430| pl5321h031d066_2          50 KB  bioconda
#     perl-parent-0.241          | pl5321hd8ed1ab_0          13 KB  conda-forge
#     perl-pathtools-3.75        | pl5321h166bdaf_0          49 KB  conda-forge
#     perl-scalar-list-utils-1.63| pl5321h166bdaf_0          50 KB  conda-forge
#     perl-storable-3.15         | pl5321hb9d3cd8_0          70 KB  conda-forge
#     perl-types-serialiser-1.01 | pl5321hdfd78af_0          13 KB  bioconda
#     popt-1.16                  |    h0b475e3_2002         184 KB  conda-forge
#     rsync-3.3.0                |       he6cb5fe_0         326 KB  conda-forge
#     tar-1.34                   |       hb2e2bae_1         893 KB  conda-forge
#     wget-1.21.4                |       hda4d442_0         752 KB  conda-forge
#     xxhash-0.8.2               |       hd590300_0          95 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       201.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   blast              bioconda/linux-64::blast-2.15.0-pl5321h6f7f691_1
#   curl               conda-forge/linux-64::curl-8.5.0-hca28451_0
#   entrez-direct      bioconda/linux-64::entrez-direct-22.4-he881be0_0
#   gettext            conda-forge/linux-64::gettext-0.22.5-he02047a_3
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.22.5-he02047a_3
#   kraken2            bioconda/linux-64::kraken2-2.1.3-pl5321hdcf5f25_2
#   libasprintf        conda-forge/linux-64::libasprintf-0.22.5-he8f35ee_3
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.22.5-he8f35ee_3
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.22.5-he02047a_3
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.22.5-he02047a_3
#   libidn2            conda-forge/linux-64::libidn2-2.3.7-hd590300_0
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   ncbi-vdb           bioconda/linux-64::ncbi-vdb-3.1.1-h4ac6f70_2
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   perl               conda-forge/linux-64::perl-5.32.1-7_hd590300_perl5
#   perl-archive-tar   bioconda/noarch::perl-archive-tar-2.40-pl5321hdfd78af_0
#   perl-carp          conda-forge/noarch::perl-carp-1.50-pl5321hd8ed1ab_0
#   perl-common-sense  conda-forge/noarch::perl-common-sense-3.75-pl5321hd8ed1ab_0
#   perl-compress-raw~ conda-forge/linux-64::perl-compress-raw-bzip2-2.201-pl5321h166bdaf_0
#   perl-compress-raw~ conda-forge/linux-64::perl-compress-raw-zlib-2.202-pl5321h166bdaf_0
#   perl-encode        conda-forge/linux-64::perl-encode-3.21-pl5321hb9d3cd8_1
#   perl-exporter      conda-forge/noarch::perl-exporter-5.74-pl5321hd8ed1ab_0
#   perl-exporter-tiny conda-forge/noarch::perl-exporter-tiny-1.002002-pl5321hd8ed1ab_0
#   perl-extutils-mak~ conda-forge/noarch::perl-extutils-makemaker-7.70-pl5321hd8ed1ab_0
#   perl-io-compress   bioconda/linux-64::perl-io-compress-2.201-pl5321hdbdd923_2
#   perl-io-zlib       bioconda/noarch::perl-io-zlib-1.14-pl5321hdfd78af_0
#   perl-json          bioconda/noarch::perl-json-4.10-pl5321hdfd78af_1
#   perl-json-xs       bioconda/linux-64::perl-json-xs-4.03-pl5321h4ac6f70_3
#   perl-list-moreuti~ bioconda/noarch::perl-list-moreutils-0.430-pl5321hdfd78af_0
#   perl-list-moreuti~ bioconda/linux-64::perl-list-moreutils-xs-0.430-pl5321h031d066_2
#   perl-parent        conda-forge/noarch::perl-parent-0.241-pl5321hd8ed1ab_0
#   perl-pathtools     conda-forge/linux-64::perl-pathtools-3.75-pl5321h166bdaf_0
#   perl-scalar-list-~ conda-forge/linux-64::perl-scalar-list-utils-1.63-pl5321h166bdaf_0
#   perl-storable      conda-forge/linux-64::perl-storable-3.15-pl5321hb9d3cd8_0
#   perl-types-serial~ bioconda/noarch::perl-types-serialiser-1.01-pl5321hdfd78af_0
#   popt               conda-forge/linux-64::popt-1.16-h0b475e3_2002
#   rsync              conda-forge/linux-64::rsync-3.3.0-he6cb5fe_0
#   tar                conda-forge/linux-64::tar-1.34-hb2e2bae_1
#   wget               conda-forge/linux-64::wget-1.21.4-hda4d442_0
#   xxhash             conda-forge/linux-64::xxhash-0.8.2-hd590300_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-hd590300_5
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.8.30-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.8.30-pyhd8ed1ab_0
#   libgcc-ng                               13.2.0-h807b86a_3 --> 14.2.0-h69a702a_1
#   libgomp                                 13.2.0-h807b86a_3 --> 14.2.0-h77fa898_1
#   openssl                                  3.2.0-hd590300_1 --> 3.3.2-hb9d3cd8_0
#
#
#
# Downloading and Extracting Packages:
# blast-2.15.0         | 146.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
# entrez-direct-22.4   | 14.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# perl-5.32.1          | 12.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ncbi-vdb-3.1.1       | 10.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# openssl-3.3.2        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# gettext-tools-0.22.5 | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# perl-encode-3.21     | 1.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# tar-1.34             | 893 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# wget-1.21.4          | 752 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# gettext-0.22.5       | 468 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsync-3.3.0          | 326 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kraken2-2.1.3        | 257 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 253 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# popt-1.16            | 184 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.22.5  | 167 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :   0% 0.00010702805008303918/1 [00:00<22:55, 1375.96s/it]
# entrez-direct-22.4   | 14.0 MB   | :   0% 0.001115570336015178/1 [00:00<02:23, 143.42s/it]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0.004207828296772089/1 [00:00<00:38, 39.10s/it]
#
# perl-5.32.1          | 12.7 MB   | :   0% 0.0012277751453917628/1 [00:00<02:26, 146.61s/it]
#
#
# blast-2.15.0         | 146.0 MB  | :   1% 0.014341758711127249/1 [00:00<00:14, 14.26s/it]
# entrez-direct-22.4   | 14.0 MB   | :  10% 0.10374804124941155/1 [00:00<00:01,  2.05s/it]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :  40% 0.3997436881933485/1 [00:00<00:00,  1.83it/s]
#
# perl-5.32.1          | 12.7 MB   | :  14% 0.13505526599309392/1 [00:00<00:01,  1.68s/it]
#
#
# blast-2.15.0         | 146.0 MB  | :   4% 0.03885118218014322/1 [00:00<00:06,  7.05s/it]
# entrez-direct-22.4   | 14.0 MB   | :  28% 0.28223929501184/1 [00:00<00:00,  1.01it/s]
#
# perl-5.32.1          | 12.7 MB   | :  37% 0.37201586905370415/1 [00:00<00:00,  1.27it/s]
#
#
# blast-2.15.0         | 146.0 MB  | :   7% 0.06635739105148429/1 [00:00<00:04,  5.26s/it]
# entrez-direct-22.4   | 14.0 MB   | :  49% 0.48638866650261753/1 [00:00<00:00,  1.36it/s]
#
# perl-5.32.1          | 12.7 MB   | :  56% 0.5561821408624685/1 [00:00<00:00,  1.47it/s]
#
#
# ncbi-vdb-3.1.1       | 10.6 MB   | :  62% 0.6210129622326686/1 [00:00<00:00,  1.74it/s]
#
#
#
#
# openssl-3.3.2        | 2.8 MB    | :   1% 0.005665696909421814/1 [00:00<01:27, 87.89s/it]
# entrez-direct-22.4   | 14.0 MB   | :  65% 0.6503775058968487/1 [00:00<00:00,  1.44it/s]
#
# blast-2.15.0         | 146.0 MB  | :   9% 0.0865856925171787/1 [00:00<00:05,  5.90s/it]
#
#
# ncbi-vdb-3.1.1       | 10.6 MB   | :  87% 0.8749969869755803/1 [00:00<00:00,  1.97it/s]
#
#
#
#
# openssl-3.3.2        | 2.8 MB    | :  76% 0.764869082771945/1 [00:00<00:00,  1.70it/s]
# entrez-direct-22.4   | 14.0 MB   | :  80% 0.8020950715949129/1 [00:00<00:00,  1.46it/s]
#
# blast-2.15.0         | 146.0 MB  | :  11% 0.10809833058386957/1 [00:00<00:04,  5.46s/it]
# entrez-direct-22.4   | 14.0 MB   | :  97% 0.9694306219971895/1 [00:00<00:00,  1.53it/s]
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  14% 0.144808951762352/1 [00:00<00:05,  6.72s/it]
#
#
#
#
#
#
# perl-encode-3.21     | 1.7 MB    | :   1% 0.009462255798548204/1 [00:00<01:44, 105.03s/it]
#
#
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  16% 0.16054207512455876/1 [00:01<00:05,  7.05s/it]
#
#
#
#
#
#
#
#
# tar-1.34             | 893 KB    | :   2% 0.01791217741626899/1 [00:01<01:01, 62.97s/it]
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | :   2% 0.019303795604097816/1 [00:01<00:58, 59.60s/it]
#
#
#
#
#
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  18% 0.18098443269041925/1 [00:01<00:05,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | :   4% 0.0355407469110093/1 [00:01<00:33, 35.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# gettext-0.22.5       | 468 KB    | :   3% 0.034172346762553915/1 [00:01<00:35, 36.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kraken2-2.1.3        | 257 KB    | :   6% 0.0623100824132987/1 [00:01<00:19, 20.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  20% 0.19703864020287512/1 [00:01<00:05,  6.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 253 KB    | :   6% 0.06316674184680986/1 [00:01<00:20, 21.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# popt-1.16            | 184 KB    | :   9% 0.08675852281753386/1 [00:01<00:14, 15.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.22.5  | 167 KB    | :  10% 0.09601162640788533/1 [00:01<00:12, 14.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  21% 0.21373501601582923/1 [00:01<00:04,  6.36s/it]
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.55s/it]
#
#
#
# blast-2.15.0         | 146.0 MB  | :  27% 0.2691755459588435/1 [00:01<00:04,  6.05s/it]
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  46% 0.45700977385457725/1 [00:02<00:01,  2.79s/it]
#
#
#
#
#
# gettext-tools-0.22.5 | 2.6 MB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
# blast-2.15.0         | 146.0 MB  | :  96% 0.9595064689944461/1 [00:03<00:00,  2.16s/it]
#
# perl-5.32.1          | 12.7 MB   | : 100% 1.0/1 [00:05<00:00,  1.58it/s]
#
#
#
#
#
#
# perl-encode-3.21     | 1.7 MB    | : 100% 1.0/1 [00:05<00:00,  5.50s/it]
#
#
#
#
#
#
# perl-encode-3.21     | 1.7 MB    | : 100% 1.0/1 [00:05<00:00,  5.50s/it]
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | : 100% 1.0/1 [00:06<00:00,  5.88s/it]
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | : 100% 1.0/1 [00:06<00:00,  5.88s/it]
#
#
#
#
#
#
#
#
# tar-1.34             | 893 KB    | : 100% 1.0/1 [00:06<00:00,  6.23s/it]
#
#
#
#
#
#
#
#
# tar-1.34             | 893 KB    | : 100% 1.0/1 [00:06<00:00,  6.23s/it]
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:06<00:00,  6.35s/it]
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:06<00:00,  6.35s/it]
#
#
# ncbi-vdb-3.1.1       | 10.6 MB   | : 100% 1.0/1 [00:07<00:00,  1.97it/s]
#
#
#
#
#
#
#
#
#
#
# wget-1.21.4          | 752 KB    | : 100% 1.0/1 [00:07<00:00,  6.93s/it]
#
#
#
#
#
#
#
#
#
#
# wget-1.21.4          | 752 KB    | : 100% 1.0/1 [00:07<00:00,  6.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# gettext-0.22.5       | 468 KB    | : 100% 1.0/1 [00:08<00:00,  8.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# gettext-0.22.5       | 468 KB    | : 100% 1.0/1 [00:08<00:00,  8.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:08<00:00,  8.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:08<00:00,  8.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kraken2-2.1.3        | 257 KB    | : 100% 1.0/1 [00:08<00:00,  8.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kraken2-2.1.3        | 257 KB    | : 100% 1.0/1 [00:08<00:00,  8.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsync-3.3.0          | 326 KB    | : 100% 1.0/1 [00:08<00:00,  8.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsync-3.3.0          | 326 KB    | : 100% 1.0/1 [00:08<00:00,  8.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 253 KB    | : 100% 1.0/1 [00:08<00:00,  8.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 253 KB    | : 100% 1.0/1 [00:08<00:00,  8.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# popt-1.16            | 184 KB    | : 100% 1.0/1 [00:09<00:00,  9.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# popt-1.16            | 184 KB    | : 100% 1.0/1 [00:09<00:00,  9.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.22.5  | 167 KB    | : 100% 1.0/1 [00:09<00:00,  9.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.22.5  | 167 KB    | : 100% 1.0/1 [00:09<00:00,  9.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# blast-2.15.0         | 146.0 MB  | : 100% 1.0/1 [00:42<00:00,  2.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
! kraken2
# Out:
# /bin/bash: line 1: kraken2: command not found

# %%
! kraken2 --use-names --threads 4 --db /content/db --fastq-input --paired /content/100-MN_1.fastq /content/100-MN_1.fastq > output.kraken
# Out:
# Unknown option: fastq-input
# Loading database information... done.
# 21098 sequences (12.70 Mbp) processed in 0.940s (1346.9 Kseq/m, 810.84 Mbp/m).
#   20452 sequences classified (96.94%)
#   646 sequences unclassified (3.06%)

# %%
! kraken2 --use-names --threads 4 --db /content/db --report output_report.txt --output kraken_output_200_mn2.txt --fastq-input /content/200-MN_2.fastq
# Out:
# Unknown option: fastq-input
# Loading database information... done.
# 69431 sequences (20.90 Mbp) processed in 1.214s (3430.3 Kseq/m, 1032.53 Mbp/m).
#   66511 sequences classified (95.79%)
#   2920 sequences unclassified (4.21%)

# %%
! kraken2
# Out:
# /bin/bash: line 1: kraken2: command not found

# %%
import pandas as pd

# Replace 'kraken_output.txt' with your Kraken output file
df = pd.read_csv('kraken_output_200_mn2.txt', sep='\t', header=None)

# %%
df
# Out:
#        0                                            1  \
# 0      C  M01771:9:000000000-L7C7K:1:1105:22891:10482
# 1      C   M01771:9:000000000-L7C7K:1:1105:7595:10482
# 2      C  M01771:9:000000000-L7C7K:1:1105:27327:10482
# 3      C  M01771:9:000000000-L7C7K:1:1105:11060:10482
# 4      C   M01771:9:000000000-L7C7K:1:1105:8512:10482
# ...   ..                                          ...
# 69426  C  M01771:9:000000000-L7C7K:1:1105:15240:13413
# 69427  C  M01771:9:000000000-L7C7K:1:1105:14189:13413
# 69428  C  M01771:9:000000000-L7C7K:1:1105:17944:13413
# 69429  C  M01771:9:000000000-L7C7K:1:1105:27760:13413
# 69430  U  M01771:9:000000000-L7C7K:1:1105:22624:13413
#
#                                                      2        3  \
# 0                                   Bacteria (taxid 2)  301|301
# 1                                   Bacteria (taxid 2)  301|301
# 2                       Lachnospiraceae (taxid 186803)  301|301
# 3                       Lachnospiraceae (taxid 186803)  301|301
# 4                             Bacteroidota (taxid 976)  301|301
# ...                                                ...      ...
# 69426                    Jeotgalicoccus (taxid 227979)  301|301
# 69427                     Bifidobacterium (taxid 1678)  301|301
# 69428              Terrabacteria group (taxid 1783272)  301|301
# 69429  Porphyromonas sp. oral taxon 275 (taxid 712435)  301|301
# 69430                           unclassified (taxid 0)  301|301
#
#                                                        4
# 0      0:46 2:4 0:5 2:1 0:1 2:3 0:97 2:5 0:7 131567:1...
# 1      131567:1 0:30 2:1 0:5 2:1 0:6 2:4 0:119 131567...
# 2      0:4 2697027:1 0:41 2:4 0:5 2:1 0:1 2:3 0:34 12...
# 3      0:24 2:5 0:7 2:5 0:1 186803:5 0:36 2:2 0:139 1...
# 4      0:4 1351:1 0:33 976:3 0:94 2:2 0:5 2:4 0:107 2...
# ...                                                  ...
# 69426  0:2 131567:1 0:15 2:3 0:24 2:4 0:10 2:5 0:29 2...
# 69427  0:30 2:4 0:7 1760:1 0:20 2:5 0:19 2:5 0:19 319...
# 69428  0:19 2:3 0:17 1783272:1 0:42 2:2 0:7 2:1 0:175...
# 69429  0:16 171549:1 0:7 171549:5 0:4 712435:1 0:7 71...
# 69430                                    0:267 |:| 0:267
#
# [69431 rows x 5 columns]

# %%
df.columns = ['sequence', 'sequence_id', 'classified', 'length', 'LCA_mapping']

# %%
df.to_csv('classified_mini8_200-mn_2.csv', index=False)

# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# **Learn the Basics** \|\| [Quickstart](quickstart_tutorial.html) \|\|
# [Tensors](tensorqs_tutorial.html) \|\| [Datasets &
# DataLoaders](data_tutorial.html) \|\|
# [Transforms](transforms_tutorial.html) \|\| [Build
# Model](buildmodel_tutorial.html) \|\|
# [Autograd](autogradqs_tutorial.html) \|\|
# [Optimization](optimization_tutorial.html) \|\| [Save & Load
# Model](saveloadrun_tutorial.html)
#
# Learn the Basics
# ================
#
# Authors: [Suraj Subramanian](https://github.com/suraj813), [Seth
# Juarez](https://github.com/sethjuarez/), [Cassie
# Breviu](https://github.com/cassieview/), [Dmitry
# Soshnikov](https://soshnikov.com/), [Ari
# Bornstein](https://github.com/aribornstein/)
#
# Most machine learning workflows involve working with data, creating
# models, optimizing model parameters, and saving the trained models. This
# tutorial introduces you to a complete ML workflow implemented in
# PyTorch, with links to learn more about each of these concepts.
#
# We\'ll use the FashionMNIST dataset to train a neural network that
# predicts if an input image belongs to one of the following classes:
# T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker,
# Bag, or Ankle boot.
#
# [This tutorial assumes a basic familiarity with Python and Deep Learning
# concepts.]{.title-ref}
#
# Running the Tutorial Code
# -------------------------
#
# You can run this tutorial in a couple of ways:
#
# -   **In the cloud**: This is the easiest way to get started! Each
#     section has a \"Run in Microsoft Learn\" and \"Run in Google Colab\"
#     link at the top, which opens an integrated notebook in Microsoft
#     Learn or Google Colab, respectively, with the code in a fully-hosted
#     environment.
# -   **Locally**: This option requires you to setup PyTorch and
#     TorchVision first on your local machine ([installation
#     instructions](https://pytorch.org/get-started/locally/)). Download
#     the notebook or copy the code into your favorite IDE.
#
# How to Use this Guide
# ---------------------
#
# If you\'re familiar with other deep learning frameworks, check out the
# [0. Quickstart](quickstart_tutorial.html) first to quickly familiarize
# yourself with PyTorch\'s API.
#
# If you\'re new to deep learning frameworks, head right into the first
# section of our step-by-step guide: [1. Tensors](tensor_tutorial.html).
#
# ::: {.toctree hidden=""}
# :::
